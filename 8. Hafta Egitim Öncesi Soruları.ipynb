# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urun(ad,fiyat):
    with open("urunler.txt", "a") as dosya:
        dosya.write(f"{ad}, {fiyat}\n")
    print("Ürün kaydedildi.")

urun(ayakkabı,40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7616\2246692741.py in <module>
#       4     print("Ürün kaydedildi.")
#       5
# ----> 6 urun(ayakkabı,40)
#
# NameError: name 'ayakkabı' is not defined

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def kelime(eski,yeni):
     with open("urunler.txt", "r+") as dosya:
          icerik= dosya.read()
          dosya.seek(0)
          dosya.write(icerik.replace(eski,yeni))
          print("değişiklik yapıldı")

kelime(ayakkabı,pantolon)          

#icerik = dosya.read() komutu, dosyanın tüm içeriğini okuyarak icerik değişkenine atar. 
# dosya.seek(0) komutu, dosya imlecinin dosyanın başına alınmasını sağlar. 
# dosya.write(icerik.replace(eski_kelime, yeni_kelime)) komutu, dosyanın içeriğindeki eski_kelime değerlerinin hepsini yeni_kelime ile değiştirir ve yeni içerikle dosyayı üzerine yazar.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7616\256056737.py in <module>
#       6           print("değişiklik yapıldı")
#       7
# ----> 8 kelime(ayakkabı,pantolon)
#
# NameError: name 'ayakkabı' is not defined

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, brand, model, year, weight):
        self.brand = brand
        self.model = model
        self.year = year
        self.weight = weight
